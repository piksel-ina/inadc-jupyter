# %% [markdown]
# ---
# title: Beginner's Guide exercise
# short_title: Exercise
# subject: Beginner Guide
# subtitle: An independent exercise applying the Open Data Cube, xarray, and plotting skills from the Beginner Guide.
# description: An independent exercise applying the Open Data Cube, xarray, and plotting skills from the Beginner Guide.
# keywords:
#   - open-data-cube
#   - odc
#   - xarray
#   - plotting
#   - spectral-indices
#   - beginner-guide
#   - exercise
# ---

# %% [markdown]
# This exercise applies the skills from notebooks 01 to 05 to a multi-year comparison of vegetation and water.
# It is designed to be completed without a worked example.[^edits]
#
# The tasks build on one another, so complete them in order.
# Open a hint only when it is needed.
# The full solution is available in a separate notebook.
#
# [^edits]: Tutorial notebooks are updated automatically, so changes made within them may be overwritten.
#     Save a working copy in a separate file to preserve any changes.

# %% [markdown]
# ## A. Objectives
#
# - Turn a point into an area of interest
# - Find and load annual satellite data
# - Inspect an `xarray.Dataset`
# - Plot a true-colour image
# - Calculate and plot NDVI and NDWI
# - Compare annual index plots

# %% [markdown]
# ## B. Preparation
#
# Import the components needed to connect to the datacube and create an area of interest from a point.
# Then open a connection to the datacube.

# %%
# Write your code here

# %% [markdown]
# ## C. Data loading
#
# Create a `0.05`-degree buffer around the following point near Kuta, Lombok.
# Display the resulting area on a map.
#
# - Latitude: `-8.81`
# - Longitude: `116.008667`
#
# Use this area to find and load annual Sentinel-2 GeoMAD data that meets the following requirements:
#
# - Time: 2022 to 2025
# - Measurements: red, green, blue, and near-infrared
# - Resolution: 30 metres

# %%
# Write your code here

# %% [markdown]
# ```{admonition} Hint
# :class: dropdown
#
# Create a buffered geometry from the point, then use its bounds to define the area of interest.
# See [notebook 03](./03_loading_data.ipynb).
#
# Use `EPSG:32750` for the output grid.
# ```

# %% [markdown]
# ## D. Dataset inspection
#
# Display the Dataset, then identify:
#
# 1. Its dimensions and number of time slices.
# 2. Its data variables.
# 3. Its coordinate reference system.

# %%
# Write your code here

# %% [markdown]
# ## E. True-colour image
#
# Plot the red, green, and blue measurements from the first time slice as a true-colour image.

# %%
# Write your code here

# %% [markdown]
# ## F. Spectral index calculation
#
# NDVI highlights vegetation, while NDWI highlights water.
# For each time slice, calculate both indices and add them to the Dataset as variables named `ndvi` and `ndwi`.
#
# $$\text{NDVI} = \frac{\text{NIR} - \text{Red}}{\text{NIR} + \text{Red}}$$
#
# $$\text{NDWI} = \frac{\text{Green} - \text{NIR}}{\text{Green} + \text{NIR}}$$

# %%
# Write your code here

# %% [markdown]
# ```{admonition} Hint
# :class: dropdown
#
# Review **Arithmetic across variables** in [notebook 04](./04_xarray_for_odc.ipynb).
# Convert the source bands to a floating-point type before dividing.
# ```

# %% [markdown]
# ## G. Index plots
#
# Plot the results using a fixed scale from -1 to 1:
#
# 1. NDVI for the first time slice using the `RdYlGn` colourmap.
# 2. NDWI for the first time slice using the `RdBu` colourmap.
# 3. NDVI for every year in a facet grid using the `RdYlGn` colourmap.

# %%
# Write your code here

# %% [markdown]
# ## H. Result interpretation
#
# Study the plots, then answer these questions:
#
# 1. Which parts of the area have the highest and lowest NDVI?
# 2. Do areas with high NDWI also have low NDVI?
# 3. Which areas change most across the annual NDVI plots?
# 4. What might explain those differences?

# %% [markdown]
# ## I. Optional challenge
#
# Create a facet grid for NDWI across every loaded year and compare it with the NDVI facet grid.

# %%
# Write your code here

# %% [markdown]
# ## J. Next steps
#
# Restart the kernel and run all cells.
# Once the notebook runs without errors, compare the approach used with the solution notebook.
