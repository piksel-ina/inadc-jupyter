# %% [markdown]
# # Getting Started with Landsat
#
# This notebook is a very simple example of the fundamentals of working with
# Earth observation data using the Open Data Cube.
#
# ## Import libraries

# %%
import os

from datacube import Datacube
from datacube.utils.aws import configure_s3_access
from odc.geo.geom import point
from piksel.utils import patch_usgs_landsat

# %% [markdown]
# ## Configure the environment

# %%
os.environ['AWS_S3_ENDPOINT'] = 's3.us-west-2.amazonaws.com'
os.environ['AWS_DEFAULT_REGION'] = 'us-west-2'

del os.environ["AWS_NO_SIGN_REQUEST"]

configure_s3_access(requester_pays=True)

dc = Datacube()

# %% [markdown]
# ## Pick a study area

# %%
# Find a location you're interested in on Google Maps and copy the coordinates
# by right-clicking on the map and clicking the coordinates

# These coords are in the order Y then X, or Latitude then Longitude
coords = -8.6252, 115.2048  # Denpasar, Bali
aoi_point = point(coords[1], coords[0], crs="EPSG:4326")
bbox = aoi_point.buffer(0.2).boundingbox

landsat_stretch = dict(vmin=7500, vmax=12000)

datetime = "2025-03"

# Preview the area
bbox.explore(zoom=8)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d1383f85ca1da027751f485362212b10 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d1383f85ca1da027751f485362212b10&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d1383f85ca1da027751f485362212b10 = L.map(
#                 &quot;map_d1383f85ca1da027751f485362212b10&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_481b79000fac7e92f554b4f479cc8afa = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_481b79000fac7e92f554b4f479cc8afa.addTo(map_d1383f85ca1da027751f485362212b10);
#
#
#
#         function geo_json_c05f17cdf091f1d052aa9cc67a399f5a_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_c05f17cdf091f1d052aa9cc67a399f5a = L.geoJson(null, {
#                 onEachFeature: geo_json_c05f17cdf091f1d052aa9cc67a399f5a_onEachFeature,
#
#             ...{
#   &quot;zoom&quot;: 8,
# }
#         });
#
#         function geo_json_c05f17cdf091f1d052aa9cc67a399f5a_add (data) {
#             geo_json_c05f17cdf091f1d052aa9cc67a399f5a
#                 .addData(data);
#         }
#             geo_json_c05f17cdf091f1d052aa9cc67a399f5a_add({&quot;geometry&quot;: {&quot;coordinates&quot;: [[[115.0048, -8.825199999999999], [115.0048, -8.4252], [115.40480000000001, -8.4252], [115.40480000000001, -8.825199999999999], [115.0048, -8.825199999999999]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;properties&quot;: {}, &quot;type&quot;: &quot;Feature&quot;});
#         geo_json_c05f17cdf091f1d052aa9cc67a399f5a.setStyle(function(feature) {return feature.properties.style;});
#
#
#
#             geo_json_c05f17cdf091f1d052aa9cc67a399f5a.addTo(map_d1383f85ca1da027751f485362212b10);
#
#
#             map_d1383f85ca1da027751f485362212b10.fitBounds(
#                 [[-8.825199999999999, 115.0048], [-8.4252, 115.40480000000001]],
#                 {}
#             );
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## Load data
#
# This uses the Datacube library to handle loading of the actual data. The `dask_chunks` argument instructs the tool to use Dask
# to lazy-load the data.

# %%
data = dc.load(
    product="ls9_c2l2_sr",
    measurements=["red", "green", "blue"],
    output_crs="EPSG:32750",
    resolution=30,
    time=datetime,
    longitude=(bbox.left, bbox.right),
    latitude=(bbox.bottom, bbox.top),
    dask_chunks={"time": 1, "x": 512, "y": 512},
    group_by="solar_day",
    patch_url=patch_usgs_landsat
)

data
# Out:
# Querying product Product(name='ls9_c2l2_sr', id_=1)
# <xarray.Dataset> Size: 52MB
# Dimensions:      (time: 4, y: 1482, x: 1475)
# Coordinates:
#   * time         (time) datetime64[ns] 32B 2025-03-01T02:23:51.539595 ... 202...
#   * y            (y) float64 12kB 9.068e+06 9.068e+06 ... 9.024e+06 9.024e+06
#   * x            (x) float64 12kB 2.803e+05 2.804e+05 ... 3.245e+05 3.246e+05
#     spatial_ref  int32 4B 32750
# Data variables:
#     red          (time, y, x) uint16 17MB dask.array<chunksize=(1, 512, 512), meta=np.ndarray>
#     green        (time, y, x) uint16 17MB dask.array<chunksize=(1, 512, 512), meta=np.ndarray>
#     blue         (time, y, x) uint16 17MB dask.array<chunksize=(1, 512, 512), meta=np.ndarray>
# Attributes:
#     crs:           EPSG:32750
#     grid_mapping:  spatial_ref

# %% [markdown]
# ## Visualise data
#
# This step uses `matplotlib` to view data as a static image. It takes a longer time to
# run than previous steps, because it's actually loading the data to prepare the images.
#
# The `to_array()` function is a trick used to be able to visualise the data as a
# red, green, blue "true colour" image.

# %%
data.to_array().plot.imshow(col="time", col_wrap=2, size=6, **landsat_stretch)
# Out:
# /srv/conda/envs/notebook/lib/python3.12/site-packages/rasterio/warp.py:387: NotGeoreferencedWarning: Dataset has no geotransform, gcps, or rpcs. The identity matrix will be returned.
#   dest = _reproject(

# %% [markdown]
# ### Interactive map
#
# This step uses another `odc` tool to visualise the data on a map.

# %%
best = data.sel(time="2025-03-17").squeeze()

# The odc.explore function will choose red, green and blue by default
# but you can choose bands with the bands=["b1", "b2", "b3"] argument
best.odc.explore(**landsat_stretch)
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e3552407d53adc04fd736d3254ca899 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#
#                 &lt;style&gt;
#                     .leaflet-image-layer {
#                         /* old android/safari*/
#                         image-rendering: -webkit-optimize-contrast;
#                         image-rendering: crisp-edges; /* safari */
#                         image-rendering: pixelated; /* chrome */
#                         image-rendering: -moz-crisp-edges; /* firefox */
#                         image-rendering: -o-crisp-edges; /* opera */
#                         -ms-interpolation-mode: nearest-neighbor; /* ie */
#                     }
#                 &lt;/style&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e3552407d53adc04fd736d3254ca899&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e3552407d53adc04fd736d3254ca899 = L.map(
#                 &quot;map_2e3552407d53adc04fd736d3254ca899&quot;,
#                 {
#                     center: [0.0, 0.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2791fd0704af71671efdfb498bf62d69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2791fd0704af71671efdfb498bf62d69.addTo(map_2e3552407d53adc04fd736d3254ca899);
#
#
#             var image_overlay_57fc04c40dcebd2af9df64bb6fa89891 = L.imageOverlay(
#                 &quot;...

# %% [markdown]
# ## Export data
#
# Here we write data to disk, again using an `odc` tool.

# %%
rgba = best.odc.to_rgba(**landsat_stretch)
rgba.odc.write_cog("landsat_sr_example.tif", overwrite=True)
# Out:
# PosixPath('landsat_sr_example.tif')
