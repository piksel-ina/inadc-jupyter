# %% [markdown]
# ---
# title: Beginner's Guide exercise
# short_title: Exercise
# subject: Beginner Guide
# subtitle: An independent exercise applying the Open Data Cube, xarray, and plotting skills from the Beginner Guide.
# description: An independent exercise applying the Open Data Cube, xarray, and plotting skills from the Beginner Guide.
# authors:
#   - name: Muhammad Taufik
#     github: taufik-shf
# keywords:
#   - open-data-cube
#   - odc
#   - xarray
#   - plotting
#   - spectral-indices
#   - beginner-guide
#   - exercise
# ---

# %% [markdown]
# This exercise puts the skills from notebooks 01 to 05 into practice. The result is a multi-year comparison of vegetation and water, built without a worked example.[^edits]
#
# Work through the tasks in order. Open a hint only when needed. The full solution is provided in a separate notebook.
#
# [^edits]: Tutorial notebooks update automatically; edits to a tutorial notebook may be overwritten on the next update. Keep a working copy in a separate file to preserve changes.

# %% [markdown]
# ## A. Objectives
#
# - Turn a point into an area of interest
# - Find and load annual satellite data
# - Inspect an `xarray.Dataset`
# - Plot a true-colour image
# - Calculate and plot NDVI and NDWI
# - Compare annual index plots

# %% [markdown]
# ## B. Getting started
#
# Import what is needed to connect to the datacube and create an area of interest from a point. Open a connection to the datacube.

# %%
# Write your code here

# %% [markdown]
# ## C. Load data
#
# Create a `0.05`-degree buffer around the following point near Kuta, Lombok. Display the resulting area on a map.
#
# - Latitude: `-8.81`
# - Longitude: `116.008667`
#
# Use this area to find and load annual Sentinel-2 GeoMAD data with these requirements:
#
# - Time: 2022 to 2025
# - Measurements: red, green, blue, and near-infrared
# - Resolution: 30 metres

# %%
# Write your code here

# %% [markdown]
# ```{admonition} Hint
# :class: dropdown
#
# Create a buffered geometry from the point and use the resulting bounds to define the area of interest. See [notebook 03](./03_loading_data.ipynb).
#
# Use `EPSG:32750` for the output grid.
# ```

# %% [markdown]
# ## D. Inspect the dataset
#
# Display the Dataset and identify:
#
# 1. Its dimensions and number of time slices.
# 2. Its data variables.
# 3. Its coordinate reference system.

# %%
# Write your code here

# %% [markdown]
# ## E. Plot a true-colour image
#
# Plot the red, green, and blue measurements from the first time slice as a true-colour image.

# %%
# Write your code here

# %% [markdown]
# ## F. Calculate spectral indices
#
# NDVI highlights vegetation; NDWI highlights water. For each time slice, calculate both indices and add them to the Dataset as variables named `ndvi` and `ndwi`.
#
# $$\text{NDVI} = \frac{\text{NIR} - \text{Red}}{\text{NIR} + \text{Red}}$$
#
# $$\text{NDWI} = \frac{\text{Green} - \text{NIR}}{\text{Green} + \text{NIR}}$$

# %%
# Write your code here

# %% [markdown]
# ```{admonition} Hint
# :class: dropdown
#
# Review **Arithmetic across variables** in [notebook 04](./04_xarray_for_odc.ipynb). Convert the source bands to a floating-point type before dividing.
# ```

# %% [markdown]
# ## G. Plot the indices
#
# Plot the results on a fixed scale from -1 to 1:
#
# 1. NDVI for the first time slice using the `RdYlGn` colourmap.
# 2. NDWI for the first time slice using the `RdBu` colourmap.
# 3. NDVI for every year in a facet grid using the `RdYlGn` colourmap.

# %%
# Write your code here

# %% [markdown]
# ## H. Interpret the results
#
# Use the plots to answer these questions:
#
# 1. Which parts of the area have the highest and lowest NDVI?
# 2. Do areas with high NDWI also have low NDVI?
# 3. Which areas change most across the annual NDVI plots?
# 4. What might explain those differences?

# %% [markdown]
# ## I. Optional challenge
#
# Create a facet grid for NDWI across every loaded year and compare it with the NDVI facet grid.

# %%
# Write your code here

# %% [markdown]
# ## J. Next steps
#
# Restart the kernel and run all cells. Once the notebook runs without errors, compare the approach with the solution notebook.
