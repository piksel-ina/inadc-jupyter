# %% [markdown]
# ---
# title: Latihan Panduan Pemula
# short_title: Latihan
# subject: Panduan Pemula
# subtitle: Latihan mandiri yang menerapkan keterampilan Open Data Cube, xarray, dan pembuatan plot.
# description: Latihan mandiri yang menerapkan keterampilan Open Data Cube, xarray, dan pembuatan plot.
# keywords:
#   - open-data-cube
#   - odc
#   - xarray
#   - plotting
#   - spectral-indices
#   - beginner-guide
#   - exercise
# ---

# %% [markdown]
# Latihan ini menggunakan keterampilan dari notebook 01 sampai 05 untuk membandingkan vegetasi dan air selama beberapa tahun.[^edits]
#
# - Kerjakan tugas secara berurutan.
# - Buka petunjuk hanya saat diperlukan.
# - Solusi lengkap tersedia dalam notebook terpisah.
#   Lihat [Solusi](./SOLUSI_Panduan_Pemula.ipynb)
#
# [^edits]: Notebook tutorial diperbarui secara otomatis, sehingga perubahan di dalamnya dapat tertimpa pada pembaruan berikutnya.
#     Simpan salinan kerja dalam file terpisah agar perubahan tetap tersimpan.

# %% [markdown]
# ## A. Tujuan
#
# - Mengubah titik menjadi wilayah kajian
# - Menemukan dan memuat data satelit tahunan
# - Memeriksa `xarray.Dataset`
# - Membuat plot citra warna alami
# - Menghitung dan membuat plot NDVI serta NDWI
# - Membandingkan plot indeks tahunan

# %% [markdown]
# ## B. Persiapan
#
# Impor komponen yang diperlukan untuk terhubung ke datacube dan membuat wilayah kajian dari sebuah titik.
# Kemudian, buka koneksi ke datacube.

# %%
# Tulis kode di sini

# %% [markdown]
# ## C. Pemuatan data
#
# Buat buffer sebesar `0.05` derajat di sekitar titik berikut yang berada di dekat Kuta, Lombok.
# Tampilkan wilayah yang dihasilkan pada peta.
#
# - Lintang: `-8.81`
# - Bujur: `116.008667`
#
# Gunakan wilayah ini untuk menemukan dan memuat data Sentinel-2 GeoMAD tahunan dengan ketentuan berikut:
#
# - Waktu: 2022 sampai 2025
# - Measurement: red, green, blue, dan near-infrared
# - Resolusi: 30 meter

# %%
# Tulis kode di sini

# %% [markdown]
# ```{admonition} Petunjuk
# :class: dropdown
#
# Buat geometri dengan buffer dari titik tersebut, lalu gunakan batas geometri yang dihasilkan untuk menetapkan wilayah kajian.
# Lihat [notebook 03](./03_memuat_data_dari_open_data_cube.ipynb) sebagai rujukan.
#
# Gunakan `EPSG:32750` untuk grid keluaran.
# ```

# %% [markdown]
# ## D. Pemeriksaan Dataset
#
# Tampilkan Dataset, lalu identifikasi informasi berikut:
#
# 1. Dimensi dan jumlah irisan waktunya.
# 2. Variabel datanya.
# 3. Sistem referensi koordinatnya.

# %%
# Tulis kode di sini

# %% [markdown]
# ## E. Plot citra warna alami
#
# Buat plot citra warna alami dari measurement red, green, dan blue pada irisan waktu pertama.

# %%
# Tulis kode di sini

# %% [markdown]
# ## F. Perhitungan indeks spektral
#
# NDVI menonjolkan vegetasi, sedangkan NDWI menonjolkan air.
# Untuk setiap irisan waktu, hitung kedua indeks tersebut dan tambahkan ke Dataset sebagai variabel bernama `ndvi` dan `ndwi`.
#
# $$\text{NDVI} = \frac{\text{NIR} - \text{Red}}{\text{NIR} + \text{Red}}$$
#
# $$\text{NDWI} = \frac{\text{Green} - \text{NIR}}{\text{Green} + \text{NIR}}$$

# %%
# Tulis kode di sini

# %% [markdown]
# ```{admonition} Petunjuk
# :class: dropdown
#
# Pelajari bagian **Operasi aritmetika antarvariabel** dalam [notebook 04](./04_xarray_untuk_open_data_cube.ipynb).
# Ubah tipe data band sumber menjadi floating-point sebelum melakukan pembagian.
# ```

# %% [markdown]
# ## G. Plot indeks
#
# Buat plot hasil dengan skala tetap dari -1 sampai 1:
#
# 1. NDVI untuk irisan waktu pertama menggunakan colormap `RdYlGn`.
# 2. NDWI untuk irisan waktu pertama menggunakan colormap `RdBu`.
# 3. NDVI untuk setiap tahun dalam facet grid menggunakan colormap `RdYlGn`.

# %%
# Tulis kode di sini

# %% [markdown]
# ## H. Interpretasi hasil
#
# Amati plot, lalu jawab pertanyaan berikut:
#
# 1. Bagian wilayah mana yang memiliki NDVI tertinggi dan terendah?
# 2. Apakah wilayah dengan NDWI tinggi juga memiliki NDVI rendah?
# 3. Wilayah mana yang paling banyak berubah di antara plot NDVI tahunan?
# 4. Apa yang mungkin menjelaskan perbedaan tersebut?

# %% [markdown]
# ## I. Tantangan opsional
#
# Buat facet grid untuk NDWI pada setiap tahun yang dimuat, lalu bandingkan dengan facet grid NDVI.

# %%
# Tulis kode di sini

# %% [markdown]
# ## J. Langkah selanjutnya
#
# Mulai ulang kernel, lalu jalankan semua sel.
# Setelah notebook berjalan tanpa kesalahan, bandingkan pendekatan yang digunakan dengan notebook solusi.
